% %%
cd('C:\Users\alice\Documents\MATLAB')

% %%
addpath C:\Users\alice\Documents\MATLAB\RHD2000_MATLAB_functions_v2_01

% %%
cd('C:\Users\alice\Documents\IntanTMSTest20190528\IntanTMSTest20190528')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The first file I opened was firstintan_190528_140517.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 0 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 60.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.5 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
whos
% Out:
%   Name                      Size                   Bytes  Class     Attributes
%
%   amplifier_channels        1x1                     2026  struct
%   amplifier_data            1x1200640            9605120  double
%   filename                  1x28                      56  char
%   frequency_parameters      1x1                     2760  struct
%   notes                     1x1                      528  struct
%   path                      1x67                     134  char
%   reference_channel         1x3                        6  char
%   spike_triggers            1x1                      736  struct
%   t_amplifier               1x1200640            9605120  double

% %%
Run1Part1 = amplifier_data;
plot(Run1Part1)
%xlim([400000 510000])

% %%
firstIntanTestSet = Run1Part1;

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The second file I opened was firstintan_190528_140617.rhd
whos
Run1Part2 = amplifier_data;
plot(Run1Part2)
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 0 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 60.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.4 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%   Name                      Size                   Bytes  Class     Attributes
%
%   Run1Part1                 1x1200640            9605120  double
%   amplifier_channels        1x1                     2026  struct
% ...

% %%
%concatenate minutes of first test set together to match up with lab notebook
firstIntanTestSet = [firstIntanTestSet, Run1Part2];

% %%
whos firstIntanTestSet
plot(firstIntanTestSet)
% Out:
%   Name                   Size                    Bytes  Class     Attributes
%
%   firstIntanTestSet      1x2401280            19210240  double

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The third file I opened was firstintan_190528_140717.rhd
whos
Run1Part3 = amplifier_data;
plot(Run1Part3)
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 0 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 26.912 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.2 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%   Name                      Size                    Bytes  Class     Attributes
%
%   Run1Part1                 1x1200640             9605120  double
%   Run1Part2                 1x1200640             9605120  double
% ...

% %%
%concatenate minutes of first test set together to match up with lab notebook
firstIntanTestSet = [firstIntanTestSet, Run1Part3];
whos firstIntanTestSet
plot(firstIntanTestSet)
% Out:
%   Name                   Size                    Bytes  Class     Attributes
%
%   firstIntanTestSet      1x2939520            23516160  double

% %% [markdown]
% **Notes on Setup**
%
% Stimulation 65% machine output, 2 spaced single pulse followed by 5 back-to-back single pulses without Fast Settle setting
%
% Followed by 2-3 spaced out sp, 5 b2b sp, and with Fast Settle
%
% Repeat both but without the air cooler on
%
% Forgot to turn off file at end so has a run on

% %% [markdown]
% # **Close up of raw Intan recording without any modifications**

% %%
samplingFreq = frequency_parameters.amplifier_sample_rate
% Out:
% samplingFreq =
%
%        20000

% %%
time_axis_1_1 = linspace(0,length(Run1Part1)/samplingFreq,length(Run1Part1));
whos time_axis_1_1
plot(time_axis_1_1,Run1Part1)
xlim([3 12])
xlabel('Seconds')
title('Two spaced out, no modifications')
% Out:
%   Name               Size                   Bytes  Class     Attributes
%
%   time_axis_1_1      1x1200640            9605120  double

% %%
plot(time_axis_1_1,Run1Part1)
xlim([19 24])
xlabel('Seconds')
title('5 back to back, no modifications')

% %%
plot(time_axis_1_1,Run1Part1)
xlim([19 19.5])
xlabel('Seconds')
title('First of five, no modifications')

% %%
plot(time_axis_1_1,Run1Part1)
xlim([19.12 19.125])
xlabel('Seconds')
title('First of five, no modifications')

% %% [markdown]
% # Close up using Fast Settle on Intan Controller

% %%
plot(time_axis_1_1,Run1Part1)
xlim([25 50])
xlabel('Seconds')
title('Fast Settle Difference Overall')

% %%
plot(time_axis_1_1,Run1Part1)
xlim([30 47])
ylim([-60 60])
xlabel('Seconds')
title('Zoom in on Fast Settle')

% %% [markdown]
% Unable to distinguish TMS from background expect for two cases without having digital input record

% %% [markdown]
% # Close up on Raw Signal without Air Cooler being on

% %%
time_axis_1_2 = linspace(0,length(Run1Part2)/samplingFreq,length(Run1Part2));
whos time_axis_1_2
plot(time_axis_1_2,Run1Part2)
xlabel('Seconds')
title('No air cooler reduces overall noise')
% Out:
%   Name               Size                   Bytes  Class     Attributes
%
%   time_axis_1_2      1x1200640            9605120  double

% %%
plot(time_axis_1_2,Run1Part2)
xlim([10 16])
xlabel('Seconds')
title('Three spaced out, no air cooler')

% %%
plot(time_axis_1_2,Run1Part2)
xlim([15.5 21])
xlabel('Seconds')
title('Five back to back, no air cooler')

% %%
plot(time_axis_1_2,Run1Part2)
xlim([15.9 16.4])
xlabel('Seconds')
title('First of 5, no air cooler')

% %%
plot(time_axis_1_2,Run1Part2)
xlim([15.935 15.94])
xlabel('Seconds')
title('First of 5, no air cooler')

% %%
plot(time_axis_1_2,Run1Part2)
xlim([28 42])
ylim([-60 60])
xlabel('Seconds')
title('Fast settle, no air cooler')

% %% [markdown]
% Again, very difficult to pick out TMS from background without event marker. Note y scale change.

% %% [markdown]
% # Adding Digital trigger for Intan's Realtime Settle Control

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was newstuff_190528_142447.rhd
whos
Run2Part1 = amplifier_data;
time_axis_2_1 = linspace(0,length(Run2Part1)/samplingFreq,length(Run2Part1));
DigIn2_1 = board_dig_in_data;

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was newstuff_190528_142704.rhd
whos
Run2Part2 = amplifier_data;
time_axis_2_2 = linspace(0,length(Run2Part2)/samplingFreq,length(Run2Part2));
DigIn2_2 = board_dig_in_data;

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was newstuff_190528_142804.rhd
whos
Run2Part3 = amplifier_data;
time_axis_2_3 = linspace(0,length(Run2Part3)/samplingFreq,length(Run2Part3));
DigIn2_3 = board_dig_in_data;

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was newstuff_190528_142904.rhd
whos
Run2Part4 = amplifier_data;
time_axis_2_4 = linspace(0,length(Run2Part4)/samplingFreq,length(Run2Part4));
DigIn2_4 = board_dig_in_data;
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 1 board digital input channel.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 31.648 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.4 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%   Name                       Size                    Bytes  Class     Attributes
%
%   Run1Part1                  1x1200640             9605120  double
%   Run1Part2                  1x1200640             9605120  double
% ...

% %%
figure
subplot(2,1,1)
plot(time_axis_2_1,Run2Part1)
xlim([22.9 22.92])
title('Voltage Signal w/ RTS')
subplot(2,1,2)
plot(time_axis_2_1,DigIn2_1)
xlim([22.9 22.92])
xlabel('Seconds')
title('Digital Input to Intan')

figure
subplot(2,1,1)
plot(time_axis_2_1,Run2Part1)
xlim([10.78 10.8])
title('Voltage Signal w/o RTS')
subplot(2,1,2)
plot(time_axis_2_1,DigIn2_1)
xlim([10.78 10.8])
xlabel('Seconds')
title('Digital Input to Intan')

figure
subplot(2,1,1)
plot(time_axis_2_1,Run2Part1)
xlim([10 25])
title('Voltage Signal')
subplot(2,1,2)
plot(time_axis_2_1,DigIn2_1)
xlim([10 25])
xlabel('Seconds')
title('Digital Input to Intan')

% %% [markdown]
% From notebook: 2 pulses without Realtime Settle control enabled, 2 pulses with it enabled - 2 ms pulse from MATLAB to Intan and TMS

% %%
figure
subplot(2,1,1)
plot(time_axis_2_2,Run2Part2)
xlim([19.578 19.598])
title('Voltage Signal w/ RTS')
subplot(2,1,2)
plot(time_axis_2_2,DigIn2_2)
xlim([19.578 19.598])
xlabel('Seconds')
title('Digital Input to Intan')

figure
subplot(2,1,1)
plot(time_axis_2_2,Run2Part2)
xlim([10.68 10.7])
title('Voltage Signal w/o RTS')
subplot(2,1,2)
plot(time_axis_2_2,DigIn2_2)
xlim([10.68 10.7])
xlabel('Seconds')
title('Digital Input to Intan')

figure
subplot(2,1,1)
plot(time_axis_2_2,Run2Part2)
xlim([10 25])
title('Voltage Signal')
subplot(2,1,2)
plot(time_axis_2_2,DigIn2_2)
xlim([10 25])
xlabel('Seconds')
title('Digital Input to Intan')

% %% [markdown]
% Two pulses without Realtime Settle followed by 2 pulses with enabled. **5 ms** pulse from MATLAB to Intan and TMS.

% %%
figure
subplot(2,1,1)
plot(time_axis_2_3,Run2Part3)
xlim([17.2 18.2])
title('Voltage Signal')
subplot(2,1,2)
plot(time_axis_2_3,DigIn2_3)
xlim([17.2 18.2])
xlabel('Seconds')
title('Digital Input to Intan')

figure
subplot(2,1,1)
plot(time_axis_2_3,Run2Part3)
xlim([15 25])
title('Voltage Signal')
subplot(2,1,2)
plot(time_axis_2_3,DigIn2_3)
xlim([15 25])
xlabel('Seconds')
title('Digital Input to Intan')

% %% [markdown]
% Disconnected from TMS. Two 5ms pulses to Realtime Settle.

% %%
figure
subplot(2,1,1)
plot(time_axis_2_4,Run2Part4)
xlim([1.99 2.03])
title('Voltage Signal')
subplot(2,1,2)
plot(time_axis_2_4,DigIn2_4)
xlim([1.99 2.03])
xlabel('Seconds')
title('Digital Input to Intan')

figure
subplot(2,1,1)
plot(time_axis_2_4,Run2Part4)
xlim([0 10])
title('Voltage Signal')
subplot(2,1,2)
plot(time_axis_2_4,DigIn2_4)
xlim([0 10])
xlabel('Seconds')
title('Digital Input to Intan')

% %% [markdown]
% Two pulses with TMS connected. 10ms leading edge.
%
% **Take home is that Input to Intan and TMS need to be separate. There is a lag in Realtime Settle activation**

% %% [markdown]
% # Separate Triggers to TMS and Intan Realtime Settle from MATLAB

% %%
clear amplifier_data 
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_145829.rhd
Run3Part1 = amplifier_data;
time_axis_3_1 = linspace(0,length(Run3Part1)/samplingFreq,length(Run3Part1));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_145929.rhd
Run3Part2 = amplifier_data;
time_axis_3_2 = linspace(0,length(Run3Part2)/samplingFreq,length(Run3Part2));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150029.rhd
Run3Part3 = amplifier_data;
time_axis_3_3 = linspace(0,length(Run3Part3)/samplingFreq,length(Run3Part3));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150129.rhd
Run3Part4 = amplifier_data;
time_axis_3_4 = linspace(0,length(Run3Part4)/samplingFreq,length(Run3Part4));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150229.rhd
Run3Part5 = amplifier_data;
time_axis_3_5 = linspace(0,length(Run3Part5)/samplingFreq,length(Run3Part5));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150329.rhd
Run3Part6 = amplifier_data;
time_axis_3_6 = linspace(0,length(Run3Part6)/samplingFreq,length(Run3Part6));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150429.rhd
Run3Part7 = amplifier_data;
time_axis_3_7 = linspace(0,length(Run3Part7)/samplingFreq,length(Run3Part7));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150529.rhd
Run3Part8 = amplifier_data;
time_axis_3_8 = linspace(0,length(Run3Part8)/samplingFreq,length(Run3Part8));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150629.rhd
Run3Part9 = amplifier_data;
time_axis_3_9 = linspace(0,length(Run3Part9)/samplingFreq,length(Run3Part9));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150729.rhd
Run3Part10 = amplifier_data;
time_axis_3_10 = linspace(0,length(Run3Part10)/samplingFreq,length(Run3Part10));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150829.rhd
Run3Part11 = amplifier_data;
time_axis_11 = linspace(0,length(Run3Part11)/samplingFreq,length(Run3Part11));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_150929.rhd
Run3Part12 = amplifier_data;
time_axis_12 = linspace(0,length(Run3Part12)/samplingFreq,length(Run3Part12));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_151029.rhd
Run3Part13 = amplifier_data;
time_axis_13 = linspace(0,length(Run3Part13)/samplingFreq,length(Run3Part13));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_151129.rhd
Run3Part14 = amplifier_data;
time_axis_14 = linspace(0,length(Run3Part14)/samplingFreq,length(Run3Part14));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_151229.rhd
Run3Part15 = amplifier_data;
time_axis_15 = linspace(0,length(Run3Part15)/samplingFreq,length(Run3Part15));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_151330.rhd
Run3Part16 = amplifier_data;
time_axis_16 = linspace(0,length(Run3Part16)/samplingFreq,length(Run3Part16));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_151430.rhd
Run3Part17 = amplifier_data;
time_axis_17 = linspace(0,length(Run3Part17)/samplingFreq,length(Run3Part17));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was thirdattempt_190528_151330.rhd
Run3Part18 = amplifier_data;
time_axis_18 = linspace(0,length(Run3Part18)/samplingFreq,length(Run3Part18));

whos
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 0 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 60.032 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.3 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% ...

% %%
figure
plot(time_axis_3_1,Run3Part1)
xlim([36.089 36.092])
title('Voltage Signal')
xlabel('Seconds')


figure
plot(time_axis_3_1,Run3Part1)
xlim([36.08 36.12])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_1,Run3Part1)
xlim([35 57])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime Settle triggered on 1 ms before and off 1 ms after TMS

% %%
figure
plot(time_axis_3_2,Run3Part2)
xlim([9.96 9.97])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_2,Run3Part2)
xlim([9.95 10])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_2,Run3Part2)
xlim([9 24])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime Settle triggered on 2 ms before and off 2 ms after TMS

% %%
plot(time_axis_3_3,Run3Part3)
xlim([20.13 20.14])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_3,Run3Part3)
xlim([20.1 20.2])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_3,Run3Part3)
xlim([19 30])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime settle triggered on 4 ms before MS and triggered off 4 ms after

% %%
figure
plot(time_axis_3_5,Run3Part5)
xlim([11.56 11.58])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_5,Run3Part5)
xlim([11.55 11.65])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_5,Run3Part5)
xlim([10 16])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime settle triggered on 8 ms before MS and triggered off 8 ms after

% %%
figure
plot(time_axis_3_6,Run3Part6)
xlim([30.05 30.095])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_6,Run3Part6)
xlim([30.0 30.5])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_6,Run3Part6)
xlim([29 40])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime settle triggered on 16 ms before MS and triggered off 16 ms after

% %%
figure
plot(time_axis_3_7,Run3Part7)
xlim([24.9 25.01])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_7,Run3Part7)
xlim([24.9 25.4])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_3_7,Run3Part7)
xlim([24 30])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime settle triggered on 32 ms before MS and triggered off 32 ms after

% %% [markdown]
% ## High pass filter applied

% %%
figure
plot(time_axis_12,Run3Part12)
xlim([8.7 9.0])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_12,Run3Part12)
xlim([8 15])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% High pass filter turned on, Realtime settle triggered on 32 ms before TMS and off 32 ms after

% %%
figure
plot(time_axis_14,Run3Part14)
xlim([31.5 31.6])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_14,Run3Part14)
xlim([31 33])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_14,Run3Part14)
xlim([30 55])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime Settle triggered on 2 ms before TMS and 2ms after, high pass filter on

% %%
figure
plot(time_axis_16,Run3Part16)
xlim([27.35 27.45])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_16,Run3Part16)
xlim([27.2 27.7])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_16,Run3Part16)
xlim([25 32])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime Settle triggered on 4 ms before TMS and off 4 ms after, high pass filter on

% %%
figure
plot(time_axis_17,Run3Part17)
xlim([20.755 20.765])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_17,Run3Part17)
xlim([20.7 21.2])
title('Voltage Signal')
xlabel('Seconds')

figure
plot(time_axis_17,Run3Part17)
xlim([19 30])
title('Voltage Signal')
xlabel('Seconds')

% %% [markdown]
% Realtime Settle **turned off**, 3 pulses with only TMS pulse from Matlab, high pass filter on
