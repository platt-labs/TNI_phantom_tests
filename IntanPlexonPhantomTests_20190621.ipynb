% %%
cd('C:\Users\alice\Documents\MATLAB')
addpath C:\Users\alice\Documents\MATLAB\RHD2000_MATLAB_functions_v2_01
cd('C:\Users\alice\Documents\IntanTMSTest20190621\IntanTMSTest20190621')

% %% [markdown]
% # No TMS Realtime Settle and Bandwidth adjustment testing
% This testing is to better understand the mechanisms of the Intan Recording System and Chip (RHD2000 family)

% %%
% First read in a whole ton of files for each condition

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS1ms_BWa_190621_112338.rhd
NoTMS_RTS1ms_BWa_v = amplifier_data;
NoTMS_RTS1ms_BWa_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS1ms_BWa_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS1ms_BWa = linspace(0,length(NoTMS_RTS1ms_BWa_v)/samplingFreq,length(NoTMS_RTS1ms_BWa_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS1ms_BWb_190621_112520.rhd
NoTMS_RTS1ms_BWb_v = amplifier_data;
NoTMS_RTS1ms_BWb_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS1ms_BWb_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS1ms_BWb = linspace(0,length(NoTMS_RTS1ms_BWb_v)/samplingFreq,length(NoTMS_RTS1ms_BWb_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS1ms_BWc_190621_113715.rhd
NoTMS_RTS1ms_BWc_v = amplifier_data;
NoTMS_RTS1ms_BWc_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS1ms_BWc_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS1ms_BWc = linspace(0,length(NoTMS_RTS1ms_BWc_v)/samplingFreq,length(NoTMS_RTS1ms_BWc_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS1ms_BWd_190621_xxxxxx.rhd
NoTMS_RTS1ms_BWd_v = amplifier_data;
NoTMS_RTS1ms_BWd_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS1ms_BWd_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS1ms_BWd = linspace(0,length(NoTMS_RTS1ms_BWd_v)/samplingFreq,length(NoTMS_RTS1ms_BWd_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS1ms_defBW_190621_110230.rhd
NoTMS_RTS1ms_defBW_v = amplifier_data;
NoTMS_RTS1ms_defBW_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS1ms_defBW_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS1ms_defBW = linspace(0,length(NoTMS_RTS1ms_defBW_v)/samplingFreq,length(NoTMS_RTS1ms_defBW_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS1ms_defBW_noDSP_190621_111246.rhd
NoTMS_RTS1ms_defBW_noDSP_v = amplifier_data;
NoTMS_RTS1ms_defBW_noDSP_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS1ms_defBW_noDSP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS1ms_defBW_noDSP = linspace(0,length(NoTMS_RTS1ms_defBW_noDSP_v)/samplingFreq,length(NoTMS_RTS1ms_defBW_noDSP_v));
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 16.288 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.4 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%
% samplingFreq =
%
%        20000
%
%
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% ...

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_BWa_190621_112301.rhd
NoTMS_RTS3ms_BWa_v = amplifier_data;
NoTMS_RTS3ms_BWa_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_BWa_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_BWa = linspace(0,length(NoTMS_RTS3ms_BWa_v)/samplingFreq,length(NoTMS_RTS3ms_BWa_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_BWb_190621_112606.rhd
NoTMS_RTS3ms_BWb_v = amplifier_data;
NoTMS_RTS3ms_BWb_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_BWb_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_BWb = linspace(0,length(NoTMS_RTS3ms_BWb_v)/samplingFreq,length(NoTMS_RTS3ms_BWb_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_BWc_190621_113626.rhd
NoTMS_RTS3ms_BWc_v = amplifier_data;
NoTMS_RTS3ms_BWc_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_BWc_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_BWc = linspace(0,length(NoTMS_RTS3ms_BWc_v)/samplingFreq,length(NoTMS_RTS3ms_BWc_v));


read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_BWd_190621_114103.rhd
NoTMS_RTS3ms_BWd_v = amplifier_data;
NoTMS_RTS3ms_BWd_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_BWd_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_BWd = linspace(0,length(NoTMS_RTS3ms_BWd_v)/samplingFreq,length(NoTMS_RTS3ms_BWd_v));


read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_BWe_190621_114555.rhd
NoTMS_RTS3ms_BWe_v = amplifier_data;
NoTMS_RTS3ms_BWe_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_BWe_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_BWe = linspace(0,length(NoTMS_RTS3ms_BWe_v)/samplingFreq,length(NoTMS_RTS3ms_BWe_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_BWf_190621_114829.rhd
NoTMS_RTS3ms_BWf_v = amplifier_data;
NoTMS_RTS3ms_BWf_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_BWf_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_BWf = linspace(0,length(NoTMS_RTS3ms_BWf_v)/samplingFreq,length(NoTMS_RTS3ms_BWf_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_defBW_190621_110133.rhd
NoTMS_RTS3ms_defBW_v = amplifier_data;
NoTMS_RTS3ms_defBW_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_defBW_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_defBW = linspace(0,length(NoTMS_RTS3ms_defBW_v)/samplingFreq,length(NoTMS_RTS3ms_defBW_v));


read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS3ms_defBW_noDSP_190621_111336.rhd
NoTMS_RTS3ms_defBW_noDSP_v = amplifier_data;
NoTMS_RTS3ms_defBW_noDSP_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS3ms_defBW_noDSP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS3ms_defBW_noDSP = linspace(0,length(NoTMS_RTS3ms_defBW_noDSP_v)/samplingFreq,length(NoTMS_RTS3ms_defBW_noDSP_v));
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 16.192 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.5 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%
% samplingFreq =
%
%        20000
%
%
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% ...

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS6ms_BWa_190621_112215.rhd
NoTMS_RTS6ms_BWa_v = amplifier_data;
NoTMS_RTS6ms_BWa_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS6ms_BWa_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS6ms_BWa = linspace(0,length(NoTMS_RTS6ms_BWa_v)/samplingFreq,length(NoTMS_RTS6ms_BWa_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS6ms_BWb_190621_112609.rhd
NoTMS_RTS6ms_BWb_v = amplifier_data;
NoTMS_RTS6ms_BWb_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS6ms_BWb_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS6ms_BWb = linspace(0,length(NoTMS_RTS6ms_BWb_v)/samplingFreq,length(NoTMS_RTS6ms_BWb_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS6ms_BWc_190621_113527.rhd
NoTMS_RTS6ms_BWc_v = amplifier_data;
NoTMS_RTS6ms_BWc_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS6ms_BWc_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS6ms_BWc = linspace(0,length(NoTMS_RTS6ms_BWc_v)/samplingFreq,length(NoTMS_RTS6ms_BWc_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS6ms_BWd_190621_114144.rhd
NoTMS_RTS6ms_BWd_v = amplifier_data;
NoTMS_RTS6ms_BWd_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS6ms_BWd_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS6ms_BWd = linspace(0,length(NoTMS_RTS6ms_BWd_v)/samplingFreq,length(NoTMS_RTS6ms_BWd_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS6ms_defBW_190621_110133.rhd
NoTMS_RTS6ms_defBW_v = amplifier_data;
NoTMS_RTS6ms_defBW_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS6ms_defBW_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS6ms_defBW = linspace(0,length(NoTMS_RTS6ms_defBW_v)/samplingFreq,length(NoTMS_RTS6ms_defBW_v));

read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoTMS_RTS6ms_defBW_noDSP_190621_111421.rhd
NoTMS_RTS6ms_defBW_noDSP_v = amplifier_data;
NoTMS_RTS6ms_defBW_noDSP_dig1 = board_dig_in_data(1,:);
NNoTMS_RTS6ms_defBW_noDSP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoTMS_RTS6ms_defBW_noDSP = linspace(0,length(NoTMS_RTS6ms_defBW_noDSP_v)/samplingFreq,length(NoTMS_RTS6ms_defBW_noDSP_v));
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 18.016 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Done!  Elapsed time: 0.5 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.
%
%
% samplingFreq =
%
%        20000
%
%
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% ...

% %% [markdown]
% ## Default Bandwidth settings with 3 RTS lengths of 1 ms, 3 ms and 6 ms

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_defBW,NoTMS_RTS6ms_defBW_v)
xlim([2 14])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_defBW, NoTMS_RTS6ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_defBW, NNoTMS_RTS6ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_defBW,NoTMS_RTS3ms_defBW_v)
xlim([14 26])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_defBW, NoTMS_RTS3ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_defBW, NNoTMS_RTS3ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([14 26])
xlabel('Seconds')
title('Digital Pulse Triggers')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_defBW,NoTMS_RTS1ms_defBW_v)
xlim([2 14])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_defBW, NoTMS_RTS1ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_defBW, NNoTMS_RTS1ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %% [markdown]
% ### Close-up on small RTS effect

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_defBW,NoTMS_RTS6ms_defBW_v)
xlim([12.58 12.62])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_defBW, NoTMS_RTS6ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_defBW, NNoTMS_RTS6ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([12.58 12.62])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_defBW,NoTMS_RTS1ms_defBW_v)
xlim([10.66 10.7])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_defBW, NoTMS_RTS1ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_defBW, NNoTMS_RTS1ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([10.66 10.7])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ### Close up of large RTS effect

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_defBW,NoTMS_RTS6ms_defBW_v)
xlim([2.56 2.6])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_defBW, NoTMS_RTS6ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_defBW, NNoTMS_RTS6ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2.56 2.6])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_defBW,NoTMS_RTS1ms_defBW_v)
xlim([8.66 8.7])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset on, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_defBW, NoTMS_RTS1ms_defBW_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_defBW, NNoTMS_RTS1ms_defBW_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([8.66 8.7])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ## Default Bandwidth settings BUT Digital DC Offset Turned Off with 3 RTS lengths of 1 ms, 3 ms and 6 ms

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP,NoTMS_RTS6ms_defBW_noDSP_v)
%xlim([2 14])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP, NoTMS_RTS6ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP, NNoTMS_RTS6ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off

xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP,NoTMS_RTS3ms_defBW_noDSP_v)

ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP, NoTMS_RTS3ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP, NNoTMS_RTS3ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off

xlabel('Seconds')
title('Digital Pulse Triggers')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP,NoTMS_RTS1ms_defBW_noDSP_v)

ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP, NoTMS_RTS1ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP, NNoTMS_RTS1ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off

xlabel('Seconds')
title('Digital Pulse Triggers')

% %% [markdown]
% ### Close up of small RTS effect

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP,NoTMS_RTS6ms_defBW_noDSP_v)
xlim([2.055 2.095])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP, NoTMS_RTS6ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP, NNoTMS_RTS6ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2.055 2.095])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP,NoTMS_RTS3ms_defBW_noDSP_v)
xlim([13.47 13.51])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP, NoTMS_RTS3ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP, NNoTMS_RTS3ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([13.47 13.51])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP,NoTMS_RTS1ms_defBW_noDSP_v)
xlim([2.23 2.27])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 1ms (typo)')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP, NoTMS_RTS1ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP, NNoTMS_RTS1ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2.23 2.27])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ### Close up of large RTS effect

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP,NoTMS_RTS6ms_defBW_noDSP_v)
xlim([9.07 9.11])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP, NoTMS_RTS6ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_defBW_noDSP, NNoTMS_RTS6ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([9.07 9.11])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP,NoTMS_RTS3ms_defBW_noDSP_v)
xlim([12.46 12.5])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP, NoTMS_RTS3ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_defBW_noDSP, NNoTMS_RTS3ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([12.46 12.5])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP,NoTMS_RTS1ms_defBW_noDSP_v)
xlim([10.24 10.28])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 3ms (typo)')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP, NoTMS_RTS1ms_defBW_noDSP_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_defBW_noDSP, NNoTMS_RTS1ms_defBW_noDSP_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([10.24 10.28])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ## Adjusted Bandwidth with RTS of 1, 3, and 6 ms
% ### Bandwidth A: Lower bandwidth: 100 Hz; DSP cutoff: 200 Hz

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_BWa,NoTMS_RTS6ms_BWa_v)
xlim([2 16])
ylabel('Voltage (a.u)')
title('No TMS, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_BWa, NoTMS_RTS6ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_BWa, NNoTMS_RTS6ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2 16])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_BWa,NoTMS_RTS3ms_BWa_v)
xlim([0 12])
ylabel('Voltage (a.u)')
title('No TMS, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_BWa, NoTMS_RTS3ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_BWa, NNoTMS_RTS3ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([0 12])
xlabel('Seconds')
title('Digital Pulse Triggers')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_BWa,NoTMS_RTS1ms_BWa_v)
xlim([1 14])
ylabel('Voltage (a.u)')
title('No TMS, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_BWa, NoTMS_RTS1ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_BWa, NNoTMS_RTS1ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([1 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %% [markdown]
% ### Close up of small RTS effect

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_BWa,NoTMS_RTS6ms_BWa_v)
xlim([7.3 7.34])
ylabel('Voltage (a.u)')
title('No TMS, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_BWa, NoTMS_RTS6ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_BWa, NNoTMS_RTS6ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([7.3 7.34])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_BWa,NoTMS_RTS3ms_BWa_v)
xlim([1.15 1.19])
ylabel('Voltage (a.u)')
title('No TMS, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_BWa, NoTMS_RTS3ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_BWa, NNoTMS_RTS3ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([1.15 1.19])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_BWa,NoTMS_RTS1ms_BWa_v)
xlim([4.22 4.26])
ylabel('Voltage (a.u)')
title('No TMS, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_BWa, NoTMS_RTS1ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_BWa, NNoTMS_RTS1ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([4.22 4.26])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ### Close up of large RTS effect

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_BWa,NoTMS_RTS6ms_BWa_v)
xlim([5.3 5.34])
ylabel('Voltage (a.u)')
title('No TMS, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_BWa, NoTMS_RTS6ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_BWa, NNoTMS_RTS6ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([5.3 5.34])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_BWa,NoTMS_RTS3ms_BWa_v)
xlim([9.17 9.21])
ylabel('Voltage (a.u)')
title('No TMS, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_BWa, NoTMS_RTS3ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_BWa, NNoTMS_RTS3ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([9.17 9.21])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_BWa,NoTMS_RTS1ms_BWa_v)
xlim([2.22 2.26])
ylabel('Voltage (a.u)')
title('No TMS, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_BWa, NoTMS_RTS1ms_BWa_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_BWa, NNoTMS_RTS1ms_BWa_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2.22 2.26])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ## Adjusted Bandwidth
% ### Bandwidth B: Lower Bandwidth:100 Hz; DSP off

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_BWb,NoTMS_RTS6ms_BWb_v)
xlim([1 14])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_BWb, NoTMS_RTS6ms_BWb_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_BWb, NNoTMS_RTS6ms_BWb_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([1 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_BWb,NoTMS_RTS3ms_BWb_v)
xlim([1 14])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_BWb, NoTMS_RTS3ms_BWb_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_BWb, NNoTMS_RTS3ms_BWb_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([1 14])
xlabel('Seconds')
title('Digital Pulse Triggers')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_BWb,NoTMS_RTS1ms_BWb_v)
xlim([2 14])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_BWb, NoTMS_RTS1ms_BWb_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_BWb, NNoTMS_RTS1ms_BWb_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([2 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_BWb,NoTMS_RTS6ms_BWb_v)
xlim([3.62 3.66])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_BWb, NoTMS_RTS6ms_BWb_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_BWb, NNoTMS_RTS6ms_BWb_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([3.62 3.66])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_BWb,NoTMS_RTS3ms_BWb_v)
xlim([1.73 1.77])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_BWb, NoTMS_RTS3ms_BWb_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_BWb, NNoTMS_RTS3ms_BWb_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([1.73 1.77])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_BWb,NoTMS_RTS1ms_BWb_v)
xlim([9.67 9.71])
ylabel('Voltage (a.u)')
title('No TMS, HP 0.1 Hz, LP 7.5 kHz, Dig DC offset OFF, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_BWb, NoTMS_RTS1ms_BWb_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_BWb, NNoTMS_RTS1ms_BWb_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off
xlim([9.67 9.71])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %% [markdown]
% ### Bandwidth C: Lower bandwidth: 1 Hz; DSP cutoff: 10 Hz

% %%
figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS6ms_BWc,NoTMS_RTS6ms_BWc_v)
%xlim([2 14])
ylabel('Voltage (a.u)')
title('No TMS, RTS 6ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS6ms_BWc, NoTMS_RTS6ms_BWc_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS6ms_BWc, NNoTMS_RTS6ms_BWc_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off

xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS3ms_BWc,NoTMS_RTS3ms_BWc_v)

ylabel('Voltage (a.u)')
title('No TMS, RTS 3ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS3ms_BWc, NoTMS_RTS3ms_BWc_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS3ms_BWc, NNoTMS_RTS3ms_BWc_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off

xlabel('Seconds')
title('Digital Pulse Triggers')


figure
subplot(2,1,1)
plot(time_axis_NoTMS_RTS1ms_BWc,NoTMS_RTS1ms_BWc_v)

ylabel('Voltage (a.u)')
title('No TMS, RTS 1ms')
subplot(2,1,2)
plot(time_axis_NoTMS_RTS1ms_BWc, NoTMS_RTS1ms_BWc_dig1,'DisplayName', 'Digital Input 1 - RTS')
hold on
plot(time_axis_NoTMS_RTS1ms_BWc, NNoTMS_RTS1ms_BWc_dig2,'DisplayName', 'Digital Input 2 - noTMS')
hold off

xlabel('Seconds')
title('Digital Pulse Triggers')
