% %%
cd('C:\Users\alice\Documents\MATLAB')
addpath C:\Users\alice\Documents\MATLAB\RHD2000_MATLAB_functions_v2_01
cd('C:\Users\alice\Documents\IntanTMSTest20190619\IntanTMSTest20190619')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoRTSnoHP_190619_140831.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 22.688 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.5 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
whos
% Out:
%   Name                       Size                  Bytes  Class     Attributes
%
%   amplifier_channels         1x1                    2026  struct
%   amplifier_data             1x453760            3630080  double
%   board_dig_in_channels      1x2                    3488  struct
%   board_dig_in_data          2x453760            7260160  double
%   filename                   1x27                     54  char
%   frequency_parameters       1x1                    2760  struct
%   notes                      1x1                     528  struct
%   path                       1x67                    134  char
%   reference_channel          1x3                       6  char
%   spike_triggers             1x1                     736  struct
%   t_amplifier                1x453760            3630080  double
%   t_dig                      1x453760            3630080  double

% %%
NoRTSnoHP_v = amplifier_data;
NoRTSnoHP_dig1 = board_dig_in_data(1,:);
NoRTSnoHP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoRTSnoHP = linspace(0,length(NoRTSnoHP_v)/samplingFreq,length(NoRTSnoHP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
xlim([16 21])
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering, 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([16 21])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
xlim([10 15])
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering, 3 spaced')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10 15])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
xlim([10.168 10.178])
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering, 1st of spaced')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.168 10.178])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')


figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
xlim([10.15 10.25])
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering, 1st of spaced')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.15 10.25])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
xlim([17.185 17.195])
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([17.185 17.195])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_NoRTSnoHP,NoRTSnoHP_v)
xlim([17.15 17.25])
ylabel('Voltage (a.u)')
title('No RTS and No High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSnoHP, NoRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([17.15 17.25])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was YesRTSnoHP_190619_141020.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 18.208 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.5 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
YesRTSnoHP_v = amplifier_data;
YesRTSnoHP_dig1 = board_dig_in_data(1,:);
YesRTSnoHP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_YesRTSnoHP = linspace(0,length(YesRTSnoHP_v)/samplingFreq,length(YesRTSnoHP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([9 15])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([9 15])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([3 9])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 3 spaced')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3 9])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([3.755 3.765])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.755 3.765])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([3.75 3.85])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.75 3.85])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([3.5 4.5])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.5 4.5])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([10.768 10.778])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.768 10.778])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([10.75 10.85])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.75 10.85])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

figure
subplot(2,1,1)
plot(time_axis_YesRTSnoHP,YesRTSnoHP_v)
xlim([10.6 11.6])
ylabel('Voltage (a.u)')
title('With RTS and No High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSnoHP, YesRTSnoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.6 11.6])
xlabel('Seconds')
title('Digital Pulse Triggers')
legend TOGGLE
legend('Location','Best')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was YesRTSYesHP_190619_141303.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 17.248 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.2 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
YesRTSYesHP_v = amplifier_data;
YesRTSYesHP_dig1 = board_dig_in_data(1,:);
YesRTSYesHP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_YesRTSYesHP = linspace(0,length(YesRTSYesHP_v)/samplingFreq,length(YesRTSYesHP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([9 14])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([9 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([3 8])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 3 spaced out')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3 8])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([3.421 3.431])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 1st spaced out')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.421 3.431])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([3.41 3.51])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 1st spaced out')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.41 3.51])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([3.3 3.8])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 1st spaced out')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.3 3.8])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([3.3 4.3])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 1st spaced out')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.3 4.3])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([10.437 10.447])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.437 10.447])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([10.42 10.52])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.42 10.52])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([10.42 10.92])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.42 10.92])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_YesRTSYesHP,YesRTSYesHP_v)
xlim([10.4 11.4])
ylabel('Voltage (a.u)')
title('With RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_YesRTSYesHP, YesRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.4 11.4])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was NoRTSYesHP_190619_141503.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 17.152 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.3 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
NoRTSYesHP_v = amplifier_data;
NoRTSYesHP_dig1 = board_dig_in_data(1,:);
NoRTSYesHP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_NoRTSYesHP = linspace(0,length(NoRTSYesHP_v)/samplingFreq,length(NoRTSYesHP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([8.5 14])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([8.5 14])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([2.5 8])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 3 spaced')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([2.5 8])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([3.0825 3.0925])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.0825 3.0925])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([3.05 3.15])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.05 3.15])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([3 3.5])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3 3.5])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([2.75 3.75])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([2.75 3.75])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([10.091 10.101])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.091 10.101])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([10.05 10.15])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10.05 10.15])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([10 10.5])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([10 10.5])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_NoRTSYesHP,NoRTSYesHP_v)
xlim([9.7 10.7])
ylabel('Voltage (a.u)')
title('No RTS and With High Pass Filtering, 2nd of 5 consecutive')
subplot(2,1,2)
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_NoRTSYesHP, NoRTSYesHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([9.7 10.7])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was 5msRTSHP_190619_142135.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 21.280 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.3 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
FiveMsRTSHP_v = amplifier_data;
FiveMsRTSHP_dig1 = board_dig_in_data(1,:);
FiveMsRTSHP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_FiveMsRTSHP = linspace(0,length(FiveMsRTSHP_v)/samplingFreq,length(FiveMsRTSHP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
xlim([9.5 15])
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([9.5 15])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
xlim([3.5 9])
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.5 9])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
xlim([3.893 3.903])
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.893 3.903])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
xlim([3.875 3.975])
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.875 3.975])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
xlim([3.8 4.3])
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.8 4.3])
xlabel('Seconds')
title('Digital Pulse Triggers')

figure
subplot(2,1,1)
plot(time_axis_FiveMsRTSHP,FiveMsRTSHP_v)
xlim([3.7 4.7])
ylabel('Voltage (a.u)')
title('5ms RTS and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FiveMsRTSHP, FiveMsRTSHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3.7 4.7])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was FastSettle_NoHP_190619_141617.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 14.944 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.3 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
FastSettle_NoHP_v = amplifier_data;
FastSettle_NoHP_dig1 = board_dig_in_data(1,:);
FastSettle_NoHP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_FastSettle_NoHP = linspace(0,length(FastSettle_NoHP_v)/samplingFreq,length(FastSettle_NoHP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_FastSettle_NoHP,FastSettle_NoHP_v)
ylim([-10 10])
ylabel('Voltage (a.u)')
title('FastSettle and WithOut High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FastSettle_NoHP, FastSettle_NoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FastSettle_NoHP, FastSettle_NoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_FastSettle_NoHP,FastSettle_NoHP_v)
ylim([-6 6])
xlim([1 7])
ylabel('Voltage (a.u)')
title('FastSettle and WithOut High Pass Filtering, 3 spaced')
subplot(2,1,2)
plot(time_axis_FastSettle_NoHP, FastSettle_NoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FastSettle_NoHP, FastSettle_NoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([1 7])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_FastSettle_NoHP,FastSettle_NoHP_v)
ylim([-6 6])
xlim([2.01 2.05])
ylabel('Voltage (a.u)')
title('FastSettle and WithOut High Pass Filtering, 1st spaced')
subplot(2,1,2)
plot(time_axis_FastSettle_NoHP, FastSettle_NoHP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FastSettle_NoHP, FastSettle_NoHP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([2.01 2.05])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
read_Intan_RHD2000_file
% This opens a GUI that allows you to select a file
%The file I opened was FastSettle_HP_190619_141729.rhd
% Out:
% Reading Intan Technologies RHD2000 Data File, Version 2.0
%
% Found 1 amplifier channel.
% Found 0 auxiliary input channels.
% Found 0 supply voltage channels.
% Found 0 board ADC channels.
% Found 2 board digital input channels.
% Found 0 board digital output channels.
% Found 0 temperature sensor channels.
%
% File contains 22.112 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
%
% Allocating memory for data...
% Reading data from file...
% 10% done...
% 20% done...
% 30% done...
% 40% done...
% 50% done...
% 60% done...
% 70% done...
% 80% done...
% 90% done...
% 100% done...
% Parsing data...
% No missing timestamps in data.
% Applying notch filter...
% 10% done...
% Done!  Elapsed time: 0.3 seconds
% Extracted data are now available in the MATLAB workspace.
% Type 'whos' to see variables.

% %%
FastSettle_HP_v = amplifier_data;
FastSettle_HP_dig1 = board_dig_in_data(1,:);
FastSettle_HP_dig2 = board_dig_in_data(2,:);
samplingFreq = frequency_parameters.amplifier_sample_rate
time_axis_FastSettle_HP = linspace(0,length(FastSettle_HP_v)/samplingFreq,length(FastSettle_HP_v));
% Out:
% samplingFreq =
%
%        20000

% %%
figure
subplot(2,1,1)
plot(time_axis_FastSettle_HP,FastSettle_HP_v)
ylim([-10 10])
ylabel('Voltage (a.u)')
title('FastSettle and With High Pass Filtering')
subplot(2,1,2)
plot(time_axis_FastSettle_HP, FastSettle_HP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FastSettle_HP, FastSettle_HP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_FastSettle_HP,FastSettle_HP_v)
ylim([-10 10])
xlim([3 8])
ylabel('Voltage (a.u)')
title('FastSettle and With High Pass Filtering, 3 spaced')
subplot(2,1,2)
plot(time_axis_FastSettle_HP, FastSettle_HP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FastSettle_HP, FastSettle_HP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([3 8])
xlabel('Seconds')
title('Digital Pulse Triggers')

% %%
figure
subplot(2,1,1)
plot(time_axis_FastSettle_HP,FastSettle_HP_v)
ylim([-10 10])
xlim([5.338 5.348])
ylabel('Voltage (a.u)')
title('FastSettle and With High Pass Filtering, 2nd of 3 spaced')
subplot(2,1,2)
plot(time_axis_FastSettle_HP, FastSettle_HP_dig1,'DisplayName', 'Digital Input 1')
hold on
plot(time_axis_FastSettle_HP, FastSettle_HP_dig2,'DisplayName', 'Digital Input 2 - TMS')
hold off
xlim([5.338 5.348])
xlabel('Seconds')
title('Digital Pulse Triggers')
